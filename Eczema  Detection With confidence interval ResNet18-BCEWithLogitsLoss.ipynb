# %%
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>1.20.0 in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torchmetrics) (24.1)
# Requirement already satisfied: torch>=2.0.0 in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torchmetrics) (2.5.1+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torchmetrics) (0.11.8)
# Requirement already satisfied: setuptools in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.11.0)
# Requirement already satisfied: filelock in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.13.1)
# Requirement already satisfied: networkx in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torch>=2.0.0->torchmetrics) (2024.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\water\.conda\envs\aihc-py39\lib\site-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.1)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd
import os
import time

# Load data files
cases_df = pd.read_csv('dataset/scin_cases.csv')
labels_df = pd.read_csv('dataset/scin_labels.csv')

# Merge data frames on case_id
merged_df = pd.merge(cases_df, labels_df, on='case_id')

# %%
merged_df.columns
# Out:
# Index(['case_id', 'source', 'release', 'year', 'age_group', 'sex_at_birth',
#        'fitzpatrick_skin_type',
#        'race_ethnicity_american_indian_or_alaska_native',
#        'race_ethnicity_asian', 'race_ethnicity_black_or_african_american',
#        'race_ethnicity_hispanic_latino_or_spanish_origin',
#        'race_ethnicity_middle_eastern_or_north_african',
#        'race_ethnicity_native_hawaiian_or_pacific_islander',
#        'race_ethnicity_white', 'race_ethnicity_other_race',
#        'race_ethnicity_prefer_not_to_answer', 'textures_raised_or_bumpy',
#        'textures_flat', 'textures_rough_or_flaky', 'textures_fluid_filled',
#        'body_parts_head_or_neck', 'body_parts_arm', 'body_parts_palm',
#        'body_parts_back_of_hand', 'body_parts_torso_front',
#        'body_parts_torso_back', 'body_parts_genitalia_or_groin',
#        'body_parts_buttocks', 'body_parts_leg', 'body_parts_foot_top_or_side',
#        'body_parts_foot_sole', 'body_parts_other',
#        'condition_symptoms_bothersome_appearance',
#        'condition_symptoms_bleeding', 'condition_symptoms_increasing_size',
#        'condition_symptoms_darkening', 'condition_symptoms_itching',
#        'condition_symptoms_burning', 'condition_symptoms_pain',
#        'condition_symptoms_no_relevant_experience', 'other_symptoms_fever',
#        'other_symptoms_chills', 'other_symptoms_fatigue',
#        'other_symptoms_joint_pain', 'other_symptoms_mouth_sores',
#        'other_symptoms_shortness_of_breath',
#        'other_symptoms_no_relevant_symptoms', 'related_category',
#        'condition_duration', 'image_1_path', 'image_2_path', 'image_3_path',
#        'image_1_shot_type', 'image_2_shot_type', 'image_3_shot_type',
#        'combined_race', 'race_ethnicity_two_or_more_after_mitigation',
#        'dermatologist_gradable_for_skin_condition_1',
#        'dermatologist_gradable_for_skin_condition_2',
#        'dermatologist_gradable_for_skin_condition_3',
#        'dermatologist_skin_condition_on_label_name',
#        'dermatologist_skin_condition_confidence',
#        'weighted_skin_condition_label',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_1',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_2',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_3',
#        'dermatologist_fitzpatrick_skin_type_label_1',
#        'dermatologist_fitzpatrick_skin_type_label_2',
#        'dermatologist_fitzpatrick_skin_type_label_3',
#        'gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us',
#        'monk_skin_tone_label_india', 'monk_skin_tone_label_us'],
#       dtype='object')

# %%
merged_df['dermatologist_gradable_for_skin_condition_1'].value_counts()
# Out:
# dermatologist_gradable_for_skin_condition_1
# DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT                     3049
# NO_IMAGE_QUALITY_INSUFFICIENT                            1925
# YES_IMAGE_QUALITY_SUFFICIENT_NO_DISCERNIBLE_PATHOLOGY      59
# Name: count, dtype: int64

# %%
merged_df['dermatologist_gradable_for_skin_condition_2'].value_counts()
# Out:
# dermatologist_gradable_for_skin_condition_2
# DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT                     464
# NO_IMAGE_QUALITY_INSUFFICIENT                            245
# YES_IMAGE_QUALITY_SUFFICIENT_NO_DISCERNIBLE_PATHOLOGY      7
# Name: count, dtype: int64

# %%
merged_df['dermatologist_gradable_for_skin_condition_3'].value_counts()
# Out:
# dermatologist_gradable_for_skin_condition_3
# DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT                     461
# NO_IMAGE_QUALITY_INSUFFICIENT                            243
# YES_IMAGE_QUALITY_SUFFICIENT_NO_DISCERNIBLE_PATHOLOGY     12
# Name: count, dtype: int64

# %%
merged_df['dermatologist_skin_condition_confidence'].value_counts()
# Out:
# dermatologist_skin_condition_confidence
# []                          1972
# [5]                          312
# [4]                          208
# [2, 2, 2]                    178
# [2, 2]                       176
#                             ...
# [3, 3, 2, 4, 1, 1]             1
# [1, 1, 2, 2, 5]                1
# [1, 4, 1, 4, 2]                1
# [4, 4, 3, 1, 1]                1
# [4, 1, 1, 1, 1, 5, 4, 2]       1
# Name: count, Length: 547, dtype: int64

# %%
merged_df['weighted_skin_condition_label'].value_counts()
# Out:
# weighted_skin_condition_label
# {}                                                                                                      1972
# {'Eczema': 1.0}                                                                                          127
# {'Urticaria': 1.0}                                                                                        85
# {'Allergic Contact Dermatitis': 1.0}                                                                      42
# {'Folliculitis': 1.0}                                                                                     38
#                                                                                                         ...
# {'Hidradenitis': 0.8, 'Abscess': 0.2}                                                                      1
# {'Drug Rash': 0.5, 'Allergic Contact Dermatitis': 0.5}                                                     1
# {'Rosacea': 0.55, 'Allergic Contact Dermatitis': 0.23, 'Cutaneous lupus': 0.23}                            1
# {'Chicken pox exanthem': 1.0}                                                                              1
# {'Leukocytoclastic Vasculitis': 0.55, 'Pigmented purpuric eruption': 0.27, 'Hypersensitivity': 0.18}       1
# Name: count, Length: 1942, dtype: int64

# %%
import pandas as pd
import ast

def extract_eczema_value(row):
    # Convert string to list and dictionary
    confidence_list = ast.literal_eval(row['dermatologist_skin_condition_confidence'])
    label_dict = ast.literal_eval(row['weighted_skin_condition_label'])

    # Initialize eczema value to 0
    eczema_value = -1 # not related to eczema or dermatitis

    # Iterate over items in label dictionary
    for i, (key, value) in enumerate(label_dict.items()):
        column_name = f'dermatologist_gradable_for_skin_condition_{i+1}'
        
#         if i < 3: # only column_name_3 exists
#             print(f"column_name={column_name}, value ={row[column_name]} enumerate i ={i}")
        
        # Check if key contains 'Eczema' or 'Dermatitis' and confidence is 4 or 5
        if i< 3 and row[column_name] == 'DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT':
            if ('eczema' in key.lower() or 'dermatitis' in key.lower()) and confidence_list[i] in [3, 4, 5]:
                eczema_value = value # eczema or dermatitis ccategory with positive samples
                break
            elif ('eczema' in key.lower() or 'dermatitis' in key.lower()) and confidence_list[i] in [1, 2]:
                eczema_value = 0 # eczema or dermatitis ccategory but negative
                break
            else:
                eczema_value = 0
        else:
            eczema_value = -1
    
    answer = -1
    if eczema_value > 0.5:
        answer = 1
    elif eczema_value >= 0.0:
        answer = 0
    else:
        answer = -1
        
    return answer

# Apply function to dataframe
merged_df['eczema'] = merged_df.apply(extract_eczema_value, axis=1)
merged_df['eczema'].value_counts()
# Out:
# eczema
# -1    3423
#  0    1243
#  1     367
# Name: count, dtype: int64

# %%
merged_df['eczema'].value_counts()
# Out:
# eczema
# -1    3423
#  0    1243
#  1     367
# Name: count, dtype: int64

# %%
merged_df[['dermatologist_skin_condition_confidence', 'weighted_skin_condition_label', 'dermatologist_gradable_for_skin_condition_1', 'dermatologist_gradable_for_skin_condition_2','dermatologist_gradable_for_skin_condition_3', 'eczema']][merged_df['eczema'] ==1].head()
# Out:
#    dermatologist_skin_condition_confidence  \
# 25                                     [5]
# 28                               [3, 1, 1]
# 35                                     [5]
# 52                                     [5]
# 56                                     [5]
#
#                         weighted_skin_condition_label  \
# 25                                    {'Eczema': 1.0}
# 28  {'Infected eczema': 0.55, 'Psoriasis': 0.23, '...
# 35                                    {'Eczema': 1.0}
# 52                                    {'Eczema': 1.0}
# 56                   {'Chronic dermatitis, NOS': 1.0}
#
#    dermatologist_gradable_for_skin_condition_1  \
# 25        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 28        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 35        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 52        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 56        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#    dermatologist_gradable_for_skin_condition_2  \
# 25                                         NaN
# 28                                         NaN
# 35                                         NaN
# 52                                         NaN
# 56                                         NaN
#
#    dermatologist_gradable_for_skin_condition_3  eczema
# 25                                         NaN       1
# 28                                         NaN       1
# 35                                         NaN       1
# 52                                         NaN       1
# 56                                         NaN       1

# %%
merged_df[['dermatologist_skin_condition_confidence', 'weighted_skin_condition_label', 'dermatologist_gradable_for_skin_condition_1', 'dermatologist_gradable_for_skin_condition_2','dermatologist_gradable_for_skin_condition_3', 'eczema']][merged_df['eczema'] ==0].head()
# Out:
#    dermatologist_skin_condition_confidence  \
# 6                          [4, 2, 5, 1, 1]
# 8                       [1, 3, 3, 2, 4, 3]
# 9                                      [3]
# 10                               [1, 5, 1]
# 11                                     [5]
#
#                         weighted_skin_condition_label  \
# 6   {'Urticaria': 0.6, 'Leukocytoclastic Vasculiti...
# 8   {'Eczema': 0.67, 'Psoriasis': 0.11, 'Acute and...
# 9                                    {'Purpura': 1.0}
# 10  {'Eczema': 0.55, 'Drug Rash': 0.23, 'Allergic ...
# 11                                 {'Urticaria': 1.0}
#
#    dermatologist_gradable_for_skin_condition_1  \
# 6                NO_IMAGE_QUALITY_INSUFFICIENT
# 8         DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 9         DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 10        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 11        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#    dermatologist_gradable_for_skin_condition_2  \
# 6         DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 8         DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
#
#    dermatologist_gradable_for_skin_condition_3  eczema
# 6         DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT       0
# 8         DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT       0
# 9                                          NaN       0
# 10                                         NaN       0
# 11                                         NaN       0

# %%
merged_df['eczema'].value_counts()
# Out:
# eczema
# -1    3423
#  0    1243
#  1     367
# Name: count, dtype: int64

# %%
#ignore non eczema dataset
merged_df = merged_df[merged_df['eczema'] != -1] 
merged_df['eczema'].value_counts()
# Out:
# eczema
# 0    1243
# 1     367
# Name: count, dtype: int64

# %%
merged_df[['dermatologist_skin_condition_confidence', 'weighted_skin_condition_label', 'eczema']]
# Out:
#      dermatologist_skin_condition_confidence  \
# 6                            [4, 2, 5, 1, 1]
# 8                         [1, 3, 3, 2, 4, 3]
# 9                                        [3]
# 10                                 [1, 5, 1]
# 11                                       [5]
# ...                                      ...
# 5018                                     [5]
# 5021                         [4, 2, 2, 2, 3]
# 5024                            [3, 4, 2, 5]
# 5028                               [5, 4, 5]
# 5032                                     [5]
#
#                           weighted_skin_condition_label  eczema
# 6     {'Urticaria': 0.6, 'Leukocytoclastic Vasculiti...       0
# 8     {'Eczema': 0.67, 'Psoriasis': 0.11, 'Acute and...       0
# 9                                      {'Purpura': 1.0}       0
# 10    {'Eczema': 0.55, 'Drug Rash': 0.23, 'Allergic ...       0
# 11                                   {'Urticaria': 1.0}       0
# ...                                                 ...     ...
# 5018                                 {'Psoriasis': 1.0}       0
# 5021  {'Eczema': 0.68, 'Scabies': 0.16, 'Hypersensit...       1
# 5024  {'Stasis Dermatitis': 0.33, 'Pigmented purpuri...       0
# 5028  {'CD - Contact dermatitis': 0.33, 'Allergic Co...       0
# 5032                              {'Folliculitis': 1.0}       0
#
# [1610 rows x 3 columns]

# %%
def calculate_image_path(row):
    if row['image_1_shot_type'] == 'CLOSE_UP' and  row['dermatologist_gradable_for_skin_condition_1'] == 'DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT': #CLOSE_UP, AT_DISTANCE
        return ''+row['image_1_path']
    elif row['image_2_shot_type'] == 'CLOSE_UP' and  row['dermatologist_gradable_for_skin_condition_2'] == 'DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT':
        return ''+row['image_2_path']
    elif row['image_3_shot_type'] == 'CLOSE_UP' and  row['dermatologist_gradable_for_skin_condition_3'] == 'DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT':
        return str(row['image_3_path'])
    else:
        return ''  # or any default value if none is found

# %%
# Create image path column
merged_df['image_path'] = merged_df.apply(calculate_image_path, axis=1)
len(merged_df)
# Out:
# 1610

# %%
merged_df = merged_df[merged_df['image_path'].apply(os.path.exists)]
len(merged_df)
# Out:
# 1148

# %%
merged_df['eczema'].value_counts()
# Out:
# eczema
# 0    910
# 1    238
# Name: count, dtype: int64

# %%
new_df = merged_df[merged_df['eczema'] ==1]['image_path'].reset_index()
new_df.loc[1]['image_path']
# Out:
# 'dataset/images/960187272475981264.png'

# %%
import torch
import matplotlib.pyplot as plt
from torchvision import transforms
from PIL import Image

# Load an image using PIL (you can replace this with your image path)
image_path = new_df.loc[50]['image_path']
image = Image.open(image_path)

# Convert the image to a PyTorch tensor
# transform =  transforms.Compose([ transforms.Resize((244, 244)),
#                                 transforms.RandomResizedCrop(192, scale=(0.8, 1.0)),
#                                 transforms.ToTensor()
#                                 ])

transform =  transforms.Compose([
#         transforms.Resize((512, 512)),
#         transforms.ColorJitter(0.5, 0.5, 0.5, 0.1),
#         transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),  
        transforms.RandomHorizontalFlip(p=0.3),  # Horizontal flip with 50% probability
        transforms.RandomVerticalFlip(p=0.3),   
        transforms.RandomResizedCrop(192, scale=(0.8, 1.0)),
        transforms.RandomAffine(degrees=0, shear=10),
#         transforms.ColorJitter(0.25, 0.25, 0.25, 0.1),
        transforms.ToTensor(),
        transforms.ConvertImageDtype(torch.float),        
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])
image_tensor = transform(image)

# Convert the image tensor from [C, H, W] to [H, W, C] for displaying
image_tensor = image_tensor.permute(1, 2, 0)

# Plot the image using matplotlib
plt.imshow(image_tensor)
plt.axis('off')  # Hide axes for better visual appearance
plt.show()
image_tensor.shape
# Out:
# torch.Size([192, 192, 3])

# %%
image_tensor.shape
# Out:
# torch.Size([192, 192, 3])

# %%
# Filter out missing labels and images
filtered_df = merged_df.dropna(subset=['eczema', 'image_path'])

# Split data into training and validation sets
train_df, val_df = train_test_split(filtered_df, test_size=0.2, random_state=42)

# %%
train_df['eczema'].value_counts()
# Out:
# eczema
# 0    727
# 1    191
# Name: count, dtype: int64

# %%
val_df['eczema'].value_counts()
# Out:
# eczema
# 0    183
# 1     47
# Name: count, dtype: int64

# %%
# Import necessary libraries
from torch.utils.data import Dataset
from PIL import Image
import torch

# Define custom dataset class
class EczemaDataset(Dataset):
    def __init__(self, df, transform):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        image_path = self.df.iloc[idx]['image_path']
        image = Image.open(image_path).convert('RGB')
        label = self.df.iloc[idx]['eczema']

        image = self.transform(image)
        label = torch.tensor(label, dtype=torch.float)

        return image, label

# %%
import torchvision.transforms as transforms

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((299, 299)),
#         transforms.ColorJitter(0.5, 0.5, 0.5, 0.1),
#         transforms.RandomHorizontalFlip(),
        
        transforms.RandomRotation(15),  
        transforms.RandomHorizontalFlip(p=0.3),  # Horizontal flip with 50% probability
        transforms.RandomVerticalFlip(p=0.3),   
        transforms.RandomResizedCrop(299, scale=(0.8, 1.0)),
        transforms.RandomAffine(degrees=0, shear=10),
        
        transforms.ToTensor(),
        transforms.ConvertImageDtype(torch.float),        
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'val': transforms.Compose([
        transforms.Resize((299, 299)),
        transforms.ToTensor(),
        transforms.ConvertImageDtype(torch.float),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# %%
import torch.nn as nn
import torchvision.models as models

# Define model
class EczemaClassifier(nn.Module):
    def __init__(self):
        super(EczemaClassifier, self).__init__()
        self.model = torchvision.models.resnet18(weights=torchvision.models.ResNet18_Weights.DEFAULT)
#         self.model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)
        # Freeze layers except for the final one
        for param in self.model.parameters():
            param.requires_grad = False        

        self.model.fc = nn.Linear(self.model.fc.in_features, 1)
        self.dropout = nn.Dropout(p=0.2)

    def forward(self, x):
        x = self.model(x)
        x = self.dropout(x)
        return x

# %%
len(train_df), len(val_df)
# Out:
# (918, 230)

# %%
def save_model(model, epoch, val_acc):
    scripted_model = torch.jit.script(model)
    torch.jit.save(scripted_model, f'resnet18-model-eczema-{epoch}-{val_acc:.4f}.pth')

# %%
# Train model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'device={device}')

from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

from torchmetrics.classification import ConfusionMatrix, Accuracy, F1Score
conf_mat = ConfusionMatrix(num_classes=2, task="BINARY").to(device)
accuracy = Accuracy(num_classes=2, task="BINARY").to(device)
f1score = F1Score(num_classes=2, task="BINARY").to(device)
# Out:
# device=cuda

# %%
import torch
from collections import Counter

# Step 1: Load and prepare your dataset (assuming your dataset is loaded into `train_df`)
# Assuming labels are stored in a column named 'label'

# Check the distribution of the classes in your dataset
class_counts = Counter(train_df['eczema'])
print(f"Class distribution: {class_counts}")

# Step 2: Calculate the number of samples for each class
num_positive = class_counts[1]
num_negative = class_counts[0]

print(f"Number of positive samples: {num_positive}")
print(f"Number of negative samples: {num_negative}")

# Step 3: Compute the pos_weight
# pos_weight is typically set to the ratio of negative to positive examples
pos_weight = num_negative / num_positive
print(f"Pos weight calculated: {pos_weight}")
# Out:
# Class distribution: Counter({0: 727, 1: 191})
# Number of positive samples: 191
# Number of negative samples: 727
# Pos weight calculated: 3.806282722513089

# %%
# Create data loaders
train_dataset = EczemaDataset(train_df, data_transforms['train'])
val_dataset = EczemaDataset(val_df, data_transforms['val'])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=400, shuffle=True) # 2500
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=128, shuffle=False)

# %%
model = EczemaClassifier().to(device)

pos_weight_tensor = torch.tensor([pos_weight]).to(device)
print(f"pos_weight_tensor={pos_weight_tensor}")
criterion = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight_tensor)

# criterion = nn.CrossEntropyLoss(weight=torch.tensor([1.0, pos_weight])).to(device)

# Initialize optimizers
# optimizer = torch.optim.SGD(model.parameters(), lr=0.001)
# optimizer = torch.optim.Adagrad(model.parameters(), lr=0.01)

# optimizer = torch.optim.RMSprop(model.parameters(), lr=0.01)
# optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

global_step = 0
global_epochs = 0
# Out:
# pos_weight_tensor=tensor([3.8063], device='cuda:0')

# %%
for epoch in range(500):
    start_time = time.time()  # Start timer

    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        labels = labels.unsqueeze(1)
        global_epochs += 1
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
                
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        writer.add_scalar('resnet-Loss/train', loss.item(), global_epochs)
                
        running_loss += loss.item()

    #scheduler step()
    scheduler.step()
        
    end_time = time.time()  # End timer
    epoch_time = end_time - start_time
    global_step += 1
    
    if global_step % 5 !=0:
        print(f'Epoch: {global_step}, Training Loss: {running_loss / len(train_loader)}, Time: {epoch_time:.2f} seconds ')
    else:
        conf_mat.reset()
        accuracy.reset()
        model.eval()
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                predicted = model(images).squeeze()
                conf_mat.update(predicted, labels)
                accuracy.update(predicted, labels)
                f1score.update(predicted, labels)
            val_acc = accuracy.compute()
            f1_acc = f1score.compute()
            print(f'Epoch: {global_step}, Training Loss: {running_loss / len(train_loader)}, Time: {epoch_time:.2f} seconds, Val Accuracy: {val_acc:.4f}, f1Score: {f1_acc:.4f}')
#             if global_step % 10 ==0:
            writer.add_scalar('resnet-Loss/validation-acc', val_acc, global_epochs)
            writer.add_scalar('resnet-Loss/validation-f1', f1_acc, global_epochs)
            print('Confusion Matrix:')
            print(conf_mat.compute())
            print(f'TP: {conf_mat.compute()[1,1]}, TN: {conf_mat.compute()[0,0]}, FP: {conf_mat.compute()[0,1]}, FN: {conf_mat.compute()[1,0]}')
            
#             save_model(model,global_step,val_acc)
# Out:
# Epoch: 1, Training Loss: 1.3192980289459229, Time: 49.43 seconds
# Epoch: 2, Training Loss: 1.214442213376363, Time: 24.38 seconds
# Epoch: 3, Training Loss: 1.2105664014816284, Time: 23.38 seconds
# Epoch: 4, Training Loss: 1.1832607587178547, Time: 23.80 seconds
# Epoch: 5, Training Loss: 1.2016896804173787, Time: 23.22 seconds, Val Accuracy: 0.7609, f1Score: 0.0000
# Confusion Matrix:
# tensor([[175,   8],
#         [ 47,   0]], device='cuda:0')
# TP: 0, TN: 175, FP: 8, FN: 47
# Epoch: 6, Training Loss: 1.10702117284139, Time: 23.81 seconds
# Epoch: 7, Training Loss: 1.100641091664632, Time: 23.81 seconds
# Epoch: 8, Training Loss: 1.13976256052653, Time: 22.52 seconds
# Epoch: 9, Training Loss: 1.1545772155125935, Time: 22.63 seconds
# Epoch: 10, Training Loss: 1.1619085470835369, Time: 23.19 seconds, Val Accuracy: 0.7565, f1Score: 0.0177
# Confusion Matrix:
# tensor([[173,  10],
#         [ 46,   1]], device='cuda:0')
# TP: 1, TN: 173, FP: 10, FN: 46
# Epoch: 11, Training Loss: 1.1193494002024333, Time: 22.44 seconds
# Epoch: 12, Training Loss: 1.1762141386667888, Time: 22.74 seconds
# Epoch: 13, Training Loss: 1.1283520857493083, Time: 22.61 seconds
# Epoch: 14, Training Loss: 1.1163012186686199, Time: 23.00 seconds
# Epoch: 15, Training Loss: 1.148629069328308, Time: 23.19 seconds, Val Accuracy: 0.7609, f1Score: 0.0568
# Confusion Matrix:
# tensor([[171,  12],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 171, FP: 12, FN: 43
# Epoch: 16, Training Loss: 1.0965023040771484, Time: 23.09 seconds
# Epoch: 17, Training Loss: 1.0766577124595642, Time: 22.78 seconds
# Epoch: 18, Training Loss: 1.1410932938257854, Time: 23.43 seconds
# Epoch: 19, Training Loss: 1.1356513500213623, Time: 23.16 seconds
# Epoch: 20, Training Loss: 1.1882672707239788, Time: 23.55 seconds, Val Accuracy: 0.7696, f1Score: 0.0681
# Confusion Matrix:
# tensor([[174,   9],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 174, FP: 9, FN: 44
# Epoch: 21, Training Loss: 1.1534386078516643, Time: 23.30 seconds
# Epoch: 22, Training Loss: 1.1033273140589397, Time: 23.15 seconds
# Epoch: 23, Training Loss: 1.1734294891357422, Time: 23.56 seconds
# Epoch: 24, Training Loss: 1.126391053199768, Time: 23.03 seconds
# Epoch: 25, Training Loss: 1.1439424753189087, Time: 23.62 seconds, Val Accuracy: 0.7652, f1Score: 0.0746
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 26, Training Loss: 1.118956168492635, Time: 22.68 seconds
# Epoch: 27, Training Loss: 1.140360911687215, Time: 22.71 seconds
# Epoch: 28, Training Loss: 1.1329870223999023, Time: 21.81 seconds
# Epoch: 29, Training Loss: 1.117185115814209, Time: 21.64 seconds
# Epoch: 30, Training Loss: 1.1442211071650188, Time: 21.95 seconds, Val Accuracy: 0.7652, f1Score: 0.0789
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 31, Training Loss: 1.1347676118214924, Time: 22.61 seconds
# Epoch: 32, Training Loss: 1.1351973215738933, Time: 22.21 seconds
# Epoch: 33, Training Loss: 1.1409882704416912, Time: 21.96 seconds
# Epoch: 34, Training Loss: 1.1443906625111897, Time: 23.04 seconds
# Epoch: 35, Training Loss: 1.1163607835769653, Time: 22.81 seconds, Val Accuracy: 0.7652, f1Score: 0.0819
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 36, Training Loss: 1.1175424257914226, Time: 22.39 seconds
# Epoch: 37, Training Loss: 1.1548922061920166, Time: 22.57 seconds
# Epoch: 38, Training Loss: 1.1499542395273845, Time: 22.02 seconds
# Epoch: 39, Training Loss: 1.1434656778971355, Time: 22.54 seconds
# Epoch: 40, Training Loss: 1.183559815088908, Time: 22.46 seconds, Val Accuracy: 0.7652, f1Score: 0.0842
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 41, Training Loss: 1.1359881162643433, Time: 22.11 seconds
# Epoch: 42, Training Loss: 1.1933119297027588, Time: 22.19 seconds
# Epoch: 43, Training Loss: 1.135242501894633, Time: 22.42 seconds
# Epoch: 44, Training Loss: 1.1565943161646526, Time: 22.19 seconds
# Epoch: 45, Training Loss: 1.1967466672261555, Time: 22.38 seconds, Val Accuracy: 0.7609, f1Score: 0.0858
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 46, Training Loss: 1.0864039460817974, Time: 22.45 seconds
# Epoch: 47, Training Loss: 1.1095314423243205, Time: 21.91 seconds
# Epoch: 48, Training Loss: 1.1642056703567505, Time: 22.26 seconds
# Epoch: 49, Training Loss: 1.1543033520380657, Time: 22.80 seconds
# Epoch: 50, Training Loss: 1.1361457109451294, Time: 23.01 seconds, Val Accuracy: 0.7609, f1Score: 0.0871
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 51, Training Loss: 1.1422778367996216, Time: 22.64 seconds
# Epoch: 52, Training Loss: 1.1353094975153606, Time: 23.64 seconds
# Epoch: 53, Training Loss: 1.1333996852238972, Time: 22.01 seconds
# Epoch: 54, Training Loss: 1.1118816137313843, Time: 22.50 seconds
# Epoch: 55, Training Loss: 1.1342255274454753, Time: 22.00 seconds, Val Accuracy: 0.7609, f1Score: 0.0881
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 56, Training Loss: 1.1170216798782349, Time: 22.09 seconds
# Epoch: 57, Training Loss: 1.1532294750213623, Time: 21.98 seconds
# Epoch: 58, Training Loss: 1.1381458044052124, Time: 21.98 seconds
# Epoch: 59, Training Loss: 1.137073278427124, Time: 22.24 seconds
# Epoch: 60, Training Loss: 1.1314324935277302, Time: 22.16 seconds, Val Accuracy: 0.7652, f1Score: 0.0891
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 61, Training Loss: 1.116647998491923, Time: 22.34 seconds
# Epoch: 62, Training Loss: 1.0951310793558757, Time: 22.67 seconds
# Epoch: 63, Training Loss: 1.1034653584162395, Time: 22.14 seconds
# Epoch: 64, Training Loss: 1.081886887550354, Time: 22.56 seconds
# Epoch: 65, Training Loss: 1.0724270542462666, Time: 22.81 seconds, Val Accuracy: 0.7696, f1Score: 0.0901
# Confusion Matrix:
# tensor([[174,   9],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 174, FP: 9, FN: 44
# Epoch: 66, Training Loss: 1.1126653750737507, Time: 22.45 seconds
# Epoch: 67, Training Loss: 1.1390005747477214, Time: 22.39 seconds
# Epoch: 68, Training Loss: 1.1443426609039307, Time: 22.77 seconds
# Epoch: 69, Training Loss: 1.1278090079625447, Time: 22.32 seconds
# Epoch: 70, Training Loss: 1.1369610230127971, Time: 22.66 seconds, Val Accuracy: 0.7609, f1Score: 0.0907
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 71, Training Loss: 1.062033196290334, Time: 22.42 seconds
# Epoch: 72, Training Loss: 1.1029054919878643, Time: 22.23 seconds
# Epoch: 73, Training Loss: 1.190823992093404, Time: 22.35 seconds
# Epoch: 74, Training Loss: 1.1430948575337727, Time: 22.44 seconds
# Epoch: 75, Training Loss: 1.1345776716868083, Time: 22.90 seconds, Val Accuracy: 0.7652, f1Score: 0.0913
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 76, Training Loss: 1.0888996918996174, Time: 22.77 seconds
# Epoch: 77, Training Loss: 1.136838714281718, Time: 22.39 seconds
# Epoch: 78, Training Loss: 1.0971228679021199, Time: 22.40 seconds
# Epoch: 79, Training Loss: 1.141221046447754, Time: 22.62 seconds
# Epoch: 80, Training Loss: 1.1182618538538616, Time: 22.39 seconds, Val Accuracy: 0.7652, f1Score: 0.0919
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 81, Training Loss: 1.1923865874608357, Time: 22.80 seconds
# Epoch: 82, Training Loss: 1.1506484349568684, Time: 22.43 seconds
# Epoch: 83, Training Loss: 1.1771172682444255, Time: 22.76 seconds
# Epoch: 84, Training Loss: 1.1194982926050823, Time: 22.61 seconds
# Epoch: 85, Training Loss: 1.1396823326746623, Time: 22.60 seconds, Val Accuracy: 0.7609, f1Score: 0.0922
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 86, Training Loss: 1.1572439670562744, Time: 22.05 seconds
# Epoch: 87, Training Loss: 1.090873658657074, Time: 22.39 seconds
# Epoch: 88, Training Loss: 1.1590036948521931, Time: 22.42 seconds
# Epoch: 89, Training Loss: 1.0845694541931152, Time: 22.80 seconds
# Epoch: 90, Training Loss: 1.1728519996007283, Time: 22.32 seconds, Val Accuracy: 0.7652, f1Score: 0.0944
# Confusion Matrix:
# tensor([[172,  11],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 172, FP: 11, FN: 43
# Epoch: 91, Training Loss: 1.1716346343358357, Time: 22.88 seconds
# Epoch: 92, Training Loss: 1.1478896935780842, Time: 22.36 seconds
# Epoch: 93, Training Loss: 1.0860597689946492, Time: 22.58 seconds
# Epoch: 94, Training Loss: 1.0935104688008626, Time: 22.39 seconds
# Epoch: 95, Training Loss: 1.1190677086512248, Time: 22.40 seconds, Val Accuracy: 0.7696, f1Score: 0.0963
# Confusion Matrix:
# tensor([[173,  10],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 173, FP: 10, FN: 43
# Epoch: 96, Training Loss: 1.1240874131520588, Time: 22.45 seconds
# Epoch: 97, Training Loss: 1.1436647574106853, Time: 22.18 seconds
# Epoch: 98, Training Loss: 1.1360396941502888, Time: 22.94 seconds
# Epoch: 99, Training Loss: 1.0949433048566182, Time: 22.79 seconds
# Epoch: 100, Training Loss: 1.1683168808619182, Time: 22.77 seconds, Val Accuracy: 0.7652, f1Score: 0.0965
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 101, Training Loss: 1.1391301949818928, Time: 22.57 seconds
# Epoch: 102, Training Loss: 1.16520889600118, Time: 21.98 seconds
# Epoch: 103, Training Loss: 1.1357239882151287, Time: 22.29 seconds
# Epoch: 104, Training Loss: 1.160347859064738, Time: 22.53 seconds
# Epoch: 105, Training Loss: 1.1411007245381672, Time: 22.36 seconds, Val Accuracy: 0.7609, f1Score: 0.0966
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 106, Training Loss: 1.1927415132522583, Time: 22.80 seconds
# Epoch: 107, Training Loss: 1.1315832535425823, Time: 22.23 seconds
# Epoch: 108, Training Loss: 1.1523374319076538, Time: 22.18 seconds
# Epoch: 109, Training Loss: 1.2066907087961833, Time: 22.00 seconds
# Epoch: 110, Training Loss: 1.1455264886220295, Time: 22.35 seconds, Val Accuracy: 0.7609, f1Score: 0.0967
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 111, Training Loss: 1.1419389247894287, Time: 22.78 seconds
# Epoch: 112, Training Loss: 1.1603120565414429, Time: 22.30 seconds
# Epoch: 113, Training Loss: 1.1332823832829793, Time: 22.97 seconds
# Epoch: 114, Training Loss: 1.126768708229065, Time: 22.82 seconds
# Epoch: 115, Training Loss: 1.1240061521530151, Time: 22.12 seconds, Val Accuracy: 0.7609, f1Score: 0.0981
# Confusion Matrix:
# tensor([[171,  12],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 171, FP: 12, FN: 43
# Epoch: 116, Training Loss: 1.149574081103007, Time: 22.54 seconds
# Epoch: 117, Training Loss: 1.1258163849512737, Time: 23.40 seconds
# Epoch: 118, Training Loss: 1.1686360041300456, Time: 22.84 seconds
# Epoch: 119, Training Loss: 1.1585766871770222, Time: 22.61 seconds
# Epoch: 120, Training Loss: 1.1333734194437664, Time: 23.16 seconds, Val Accuracy: 0.7696, f1Score: 0.0994
# Confusion Matrix:
# tensor([[173,  10],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 173, FP: 10, FN: 43
# Epoch: 121, Training Loss: 1.1229692697525024, Time: 22.53 seconds
# Epoch: 122, Training Loss: 1.152449647585551, Time: 23.03 seconds
# Epoch: 123, Training Loss: 1.1245061159133911, Time: 22.42 seconds
# Epoch: 124, Training Loss: 1.0757562518119812, Time: 22.99 seconds
# Epoch: 125, Training Loss: 1.1315048933029175, Time: 23.01 seconds, Val Accuracy: 0.7652, f1Score: 0.1007
# Confusion Matrix:
# tensor([[172,  11],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 172, FP: 11, FN: 43
# Epoch: 126, Training Loss: 1.1690369844436646, Time: 23.21 seconds
# Epoch: 127, Training Loss: 1.1398719946543376, Time: 23.21 seconds
# Epoch: 128, Training Loss: 1.0984881321589153, Time: 23.21 seconds
# Epoch: 129, Training Loss: 1.1469058990478516, Time: 23.19 seconds
# Epoch: 130, Training Loss: 1.12921138604482, Time: 23.51 seconds, Val Accuracy: 0.7609, f1Score: 0.1017
# Confusion Matrix:
# tensor([[171,  12],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 171, FP: 12, FN: 43
# Epoch: 131, Training Loss: 1.1051523288091023, Time: 22.84 seconds
# Epoch: 132, Training Loss: 1.0855749050776164, Time: 22.53 seconds
# Epoch: 133, Training Loss: 1.1855701208114624, Time: 23.01 seconds
# Epoch: 134, Training Loss: 1.1491470734278362, Time: 23.00 seconds
# Epoch: 135, Training Loss: 1.1293970743815105, Time: 22.81 seconds, Val Accuracy: 0.7609, f1Score: 0.1016
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 136, Training Loss: 1.127949555714925, Time: 22.57 seconds
# Epoch: 137, Training Loss: 1.1625696023305256, Time: 22.67 seconds
# Epoch: 138, Training Loss: 1.154723048210144, Time: 22.75 seconds
# Epoch: 139, Training Loss: 1.152003566424052, Time: 22.66 seconds
# Epoch: 140, Training Loss: 1.1165440877278645, Time: 23.00 seconds, Val Accuracy: 0.7696, f1Score: 0.1016
# Confusion Matrix:
# tensor([[174,   9],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 174, FP: 9, FN: 44
# Epoch: 141, Training Loss: 1.0730675061543782, Time: 22.83 seconds
# Epoch: 142, Training Loss: 1.1761972904205322, Time: 22.35 seconds
# Epoch: 143, Training Loss: 1.121753732363383, Time: 22.57 seconds
# Epoch: 144, Training Loss: 1.089723030726115, Time: 22.69 seconds
# Epoch: 145, Training Loss: 1.095499316851298, Time: 22.16 seconds, Val Accuracy: 0.7609, f1Score: 0.1015
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 146, Training Loss: 1.1513239940007527, Time: 22.07 seconds
# Epoch: 147, Training Loss: 1.1613279978434246, Time: 22.19 seconds
# Epoch: 148, Training Loss: 1.1814737717310588, Time: 22.17 seconds
# Epoch: 149, Training Loss: 1.1348197062810261, Time: 22.01 seconds
# Epoch: 150, Training Loss: 1.122426708539327, Time: 22.30 seconds, Val Accuracy: 0.7609, f1Score: 0.1014
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 151, Training Loss: 1.162572940190633, Time: 22.41 seconds
# Epoch: 152, Training Loss: 1.1069291432698567, Time: 22.43 seconds
# Epoch: 153, Training Loss: 1.1047828594843547, Time: 22.17 seconds
# Epoch: 154, Training Loss: 1.1241660912831624, Time: 22.79 seconds
# Epoch: 155, Training Loss: 1.1026374499003093, Time: 22.20 seconds, Val Accuracy: 0.7652, f1Score: 0.1013
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 156, Training Loss: 1.1075516144434612, Time: 22.10 seconds
# Epoch: 157, Training Loss: 1.1097965240478516, Time: 22.52 seconds
# Epoch: 158, Training Loss: 1.1547300815582275, Time: 23.30 seconds
# Epoch: 159, Training Loss: 1.1031349500020344, Time: 22.39 seconds
# Epoch: 160, Training Loss: 1.1678699254989624, Time: 22.18 seconds, Val Accuracy: 0.7652, f1Score: 0.1013
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 161, Training Loss: 1.1391558249791462, Time: 23.05 seconds
# Epoch: 162, Training Loss: 1.1601306200027466, Time: 23.21 seconds
# Epoch: 163, Training Loss: 1.1136398712793987, Time: 22.79 seconds
# Epoch: 164, Training Loss: 1.1389095385869343, Time: 23.82 seconds
# Epoch: 165, Training Loss: 1.1619222561518352, Time: 22.96 seconds, Val Accuracy: 0.7609, f1Score: 0.1012
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 166, Training Loss: 1.1484804153442383, Time: 22.83 seconds
# Epoch: 167, Training Loss: 1.1346371571222942, Time: 23.17 seconds
# Epoch: 168, Training Loss: 1.1087631384531658, Time: 23.17 seconds
# Epoch: 169, Training Loss: 1.0977156162261963, Time: 22.64 seconds
# Epoch: 170, Training Loss: 1.1562941471735637, Time: 22.69 seconds, Val Accuracy: 0.7609, f1Score: 0.1011
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 171, Training Loss: 1.1574528614679973, Time: 23.46 seconds
# Epoch: 172, Training Loss: 1.1149794658025105, Time: 23.33 seconds
# Epoch: 173, Training Loss: 1.1263393958409627, Time: 23.15 seconds
# Epoch: 174, Training Loss: 1.1398343245188396, Time: 22.89 seconds
# Epoch: 175, Training Loss: 1.1418401002883911, Time: 23.34 seconds, Val Accuracy: 0.7652, f1Score: 0.1011
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 176, Training Loss: 1.1750552256902058, Time: 23.22 seconds
# Epoch: 177, Training Loss: 1.1651256879170735, Time: 23.06 seconds
# Epoch: 178, Training Loss: 1.1077472766240437, Time: 23.02 seconds
# Epoch: 179, Training Loss: 1.087807536125183, Time: 23.37 seconds
# Epoch: 180, Training Loss: 1.1326713959376018, Time: 23.20 seconds, Val Accuracy: 0.7696, f1Score: 0.1011
# Confusion Matrix:
# tensor([[174,   9],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 174, FP: 9, FN: 44
# Epoch: 181, Training Loss: 1.1287943522135417, Time: 22.76 seconds
# Epoch: 182, Training Loss: 1.1644041140874226, Time: 22.67 seconds
# Epoch: 183, Training Loss: 1.130204399426778, Time: 22.63 seconds
# Epoch: 184, Training Loss: 1.1427829662958782, Time: 22.30 seconds
# Epoch: 185, Training Loss: 1.131156365076701, Time: 22.44 seconds, Val Accuracy: 0.7652, f1Score: 0.1011
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 186, Training Loss: 1.155950665473938, Time: 22.83 seconds
# Epoch: 187, Training Loss: 1.143774112065633, Time: 22.67 seconds
# Epoch: 188, Training Loss: 1.094149927298228, Time: 22.79 seconds
# Epoch: 189, Training Loss: 1.1395753224690754, Time: 22.76 seconds
# Epoch: 190, Training Loss: 1.146116852760315, Time: 22.22 seconds, Val Accuracy: 0.7565, f1Score: 0.1010
# Confusion Matrix:
# tensor([[171,  12],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 171, FP: 12, FN: 44
# Epoch: 191, Training Loss: 1.1200483640034993, Time: 22.08 seconds
# Epoch: 192, Training Loss: 1.171063780784607, Time: 22.04 seconds
# Epoch: 193, Training Loss: 1.1228692531585693, Time: 22.17 seconds
# Epoch: 194, Training Loss: 1.0931620200475056, Time: 22.19 seconds
# Epoch: 195, Training Loss: 1.1304119030634563, Time: 22.20 seconds, Val Accuracy: 0.7609, f1Score: 0.1009
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 196, Training Loss: 1.1882740656534831, Time: 22.39 seconds
# Epoch: 197, Training Loss: 1.107117732365926, Time: 22.19 seconds
# Epoch: 198, Training Loss: 1.1174023151397705, Time: 22.34 seconds
# Epoch: 199, Training Loss: 1.177146037419637, Time: 22.80 seconds
# Epoch: 200, Training Loss: 1.1540991465250652, Time: 22.99 seconds, Val Accuracy: 0.7565, f1Score: 0.1008
# Confusion Matrix:
# tensor([[171,  12],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 171, FP: 12, FN: 44
# Epoch: 201, Training Loss: 1.1916981935501099, Time: 23.43 seconds
# Epoch: 202, Training Loss: 1.1732989152272542, Time: 23.99 seconds
# Epoch: 203, Training Loss: 1.10700261592865, Time: 23.74 seconds
# Epoch: 204, Training Loss: 1.1202203035354614, Time: 23.97 seconds
# Epoch: 205, Training Loss: 1.1204725901285808, Time: 23.47 seconds, Val Accuracy: 0.7609, f1Score: 0.1007
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 206, Training Loss: 1.1107957760492961, Time: 23.19 seconds
# Epoch: 207, Training Loss: 1.1515794197718303, Time: 23.41 seconds
# Epoch: 208, Training Loss: 1.1221562623977661, Time: 22.00 seconds
# Epoch: 209, Training Loss: 1.1311287482579548, Time: 23.41 seconds
# Epoch: 210, Training Loss: 1.1792303323745728, Time: 22.78 seconds, Val Accuracy: 0.7609, f1Score: 0.1007
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 211, Training Loss: 1.123752514521281, Time: 23.01 seconds
# Epoch: 212, Training Loss: 1.1300872564315796, Time: 22.87 seconds
# Epoch: 213, Training Loss: 1.133183479309082, Time: 22.79 seconds
# Epoch: 214, Training Loss: 1.1724913120269775, Time: 22.97 seconds
# Epoch: 215, Training Loss: 1.1388510862986247, Time: 23.43 seconds, Val Accuracy: 0.7609, f1Score: 0.1006
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 216, Training Loss: 1.1498338381449382, Time: 23.29 seconds
# Epoch: 217, Training Loss: 1.155440886815389, Time: 23.19 seconds
# Epoch: 218, Training Loss: 1.1498916149139404, Time: 23.61 seconds
# Epoch: 219, Training Loss: 1.1547809839248657, Time: 23.55 seconds
# Epoch: 220, Training Loss: 1.1686181624730427, Time: 23.59 seconds, Val Accuracy: 0.7609, f1Score: 0.1006
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 221, Training Loss: 1.1018821398417156, Time: 23.15 seconds
# Epoch: 222, Training Loss: 1.1258894602457683, Time: 22.64 seconds
# Epoch: 223, Training Loss: 1.1423380374908447, Time: 22.77 seconds
# Epoch: 224, Training Loss: 1.0773066480954487, Time: 22.82 seconds
# Epoch: 225, Training Loss: 1.1313070853551228, Time: 22.78 seconds, Val Accuracy: 0.7696, f1Score: 0.1006
# Confusion Matrix:
# tensor([[174,   9],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 174, FP: 9, FN: 44
# Epoch: 226, Training Loss: 1.105466405550639, Time: 23.25 seconds
# Epoch: 227, Training Loss: 1.1553484598795574, Time: 22.79 seconds
# Epoch: 228, Training Loss: 1.1616535981496174, Time: 22.96 seconds
# Epoch: 229, Training Loss: 1.1446566581726074, Time: 22.58 seconds
# Epoch: 230, Training Loss: 1.137835423151652, Time: 22.43 seconds, Val Accuracy: 0.7652, f1Score: 0.1012
# Confusion Matrix:
# tensor([[172,  11],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 172, FP: 11, FN: 43
# Epoch: 231, Training Loss: 1.141430656115214, Time: 23.09 seconds
# Epoch: 232, Training Loss: 1.140315334002177, Time: 22.59 seconds
# Epoch: 233, Training Loss: 1.1274161736170452, Time: 22.41 seconds
# Epoch: 234, Training Loss: 1.1207789182662964, Time: 22.39 seconds
# Epoch: 235, Training Loss: 1.1216290791829426, Time: 22.60 seconds, Val Accuracy: 0.7652, f1Score: 0.1012
# Confusion Matrix:
# tensor([[173,  10],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 173, FP: 10, FN: 44
# Epoch: 236, Training Loss: 1.1513690948486328, Time: 22.51 seconds
# Epoch: 237, Training Loss: 1.1443624099095662, Time: 22.38 seconds
# Epoch: 238, Training Loss: 1.1357745329538982, Time: 22.58 seconds
# Epoch: 239, Training Loss: 1.1150081157684326, Time: 22.82 seconds
# Epoch: 240, Training Loss: 1.1406286160151164, Time: 22.42 seconds, Val Accuracy: 0.7696, f1Score: 0.1012
# Confusion Matrix:
# tensor([[174,   9],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 174, FP: 9, FN: 44
# Epoch: 241, Training Loss: 1.1123849153518677, Time: 22.83 seconds
# Epoch: 242, Training Loss: 1.1010864973068237, Time: 22.94 seconds
# Epoch: 243, Training Loss: 1.1528788407643635, Time: 22.18 seconds
# Epoch: 244, Training Loss: 1.1365346511205037, Time: 22.28 seconds
# Epoch: 245, Training Loss: 1.1347543398539226, Time: 22.00 seconds, Val Accuracy: 0.7609, f1Score: 0.1011
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 246, Training Loss: 1.120339274406433, Time: 22.63 seconds
# Epoch: 247, Training Loss: 1.1805988550186157, Time: 22.60 seconds
# Epoch: 248, Training Loss: 1.1502810716629028, Time: 22.34 seconds
# Epoch: 249, Training Loss: 1.1392688751220703, Time: 22.75 seconds
# Epoch: 250, Training Loss: 1.1021686395009358, Time: 23.03 seconds, Val Accuracy: 0.7609, f1Score: 0.1011
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 251, Training Loss: 1.150127371152242, Time: 22.69 seconds
# Epoch: 252, Training Loss: 1.1543278296788533, Time: 22.79 seconds
# Epoch: 253, Training Loss: 1.150517423947652, Time: 22.17 seconds
# Epoch: 254, Training Loss: 1.1136611700057983, Time: 22.58 seconds
# Epoch: 255, Training Loss: 1.12545112768809, Time: 22.60 seconds, Val Accuracy: 0.7609, f1Score: 0.1010
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 256, Training Loss: 1.0814841787020366, Time: 22.41 seconds
# Epoch: 257, Training Loss: 1.1085893710454304, Time: 22.78 seconds
# Epoch: 258, Training Loss: 1.1080539226531982, Time: 22.81 seconds
# Epoch: 259, Training Loss: 1.0988787412643433, Time: 22.21 seconds
# Epoch: 260, Training Loss: 1.1376190980275471, Time: 22.36 seconds, Val Accuracy: 0.7652, f1Score: 0.1016
# Confusion Matrix:
# tensor([[172,  11],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 172, FP: 11, FN: 43
# Epoch: 261, Training Loss: 1.1429170370101929, Time: 22.80 seconds
# Epoch: 262, Training Loss: 1.1289514700571697, Time: 22.45 seconds
# Epoch: 263, Training Loss: 1.100298523902893, Time: 22.78 seconds
# Epoch: 264, Training Loss: 1.129625638326009, Time: 22.92 seconds
# Epoch: 265, Training Loss: 1.1259588797887166, Time: 22.82 seconds, Val Accuracy: 0.7609, f1Score: 0.1015
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 266, Training Loss: 1.1163852612177532, Time: 22.61 seconds
# Epoch: 267, Training Loss: 1.1501259009043376, Time: 22.84 seconds
# Epoch: 268, Training Loss: 1.0627315640449524, Time: 22.57 seconds
# Epoch: 269, Training Loss: 1.1099960803985596, Time: 22.41 seconds
# Epoch: 270, Training Loss: 1.116418480873108, Time: 22.63 seconds, Val Accuracy: 0.7609, f1Score: 0.1015
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 271, Training Loss: 1.1163770357767742, Time: 22.64 seconds
# Epoch: 272, Training Loss: 1.096087674299876, Time: 22.58 seconds
# Epoch: 273, Training Loss: 1.152237057685852, Time: 22.39 seconds
# Epoch: 274, Training Loss: 1.1772572994232178, Time: 22.18 seconds
# Epoch: 275, Training Loss: 1.098028540611267, Time: 22.21 seconds, Val Accuracy: 0.7609, f1Score: 0.1014
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 276, Training Loss: 1.1344798803329468, Time: 22.58 seconds
# Epoch: 277, Training Loss: 1.1678434610366821, Time: 22.65 seconds
# Epoch: 278, Training Loss: 1.1199795007705688, Time: 22.59 seconds
# Epoch: 279, Training Loss: 1.1949734687805176, Time: 22.54 seconds
# Epoch: 280, Training Loss: 1.0797839959462483, Time: 23.05 seconds, Val Accuracy: 0.7609, f1Score: 0.1014
# Confusion Matrix:
# tensor([[172,  11],
#         [ 44,   3]], device='cuda:0')
# TP: 3, TN: 172, FP: 11, FN: 44
# Epoch: 281, Training Loss: 1.1768579483032227, Time: 22.22 seconds
# Epoch: 282, Training Loss: 1.164204200108846, Time: 23.24 seconds
# Epoch: 283, Training Loss: 1.1338201363881428, Time: 21.80 seconds
# Epoch: 284, Training Loss: 1.1402860085169475, Time: 22.76 seconds
# Epoch: 285, Training Loss: 1.1210908889770508, Time: 23.20 seconds, Val Accuracy: 0.7652, f1Score: 0.1019
# Confusion Matrix:
# tensor([[172,  11],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 172, FP: 11, FN: 43
# Epoch: 286, Training Loss: 1.1541131734848022, Time: 23.05 seconds
# Epoch: 287, Training Loss: 1.1311583121617634, Time: 22.60 seconds
# Epoch: 288, Training Loss: 1.1344612042109172, Time: 23.12 seconds
# Epoch: 289, Training Loss: 1.158891995747884, Time: 22.82 seconds
# Epoch: 290, Training Loss: 1.1343730688095093, Time: 23.25 seconds, Val Accuracy: 0.7696, f1Score: 0.1024
# Confusion Matrix:
# tensor([[173,  10],
#         [ 43,   4]], device='cuda:0')
# TP: 4, TN: 173, FP: 10, FN: 43

# %%
# scripted_model = torch.jit.script(model)
# torch.jit.save(scripted_model, 'resnet18-model-eczema-0.7815.pth')

# %%
# loaded_model = loaded_model = torch.jit.load('resnet18-model-eczema-0.7815.pth')
